# %% [markdown]
# # <center> Covid-19 Deaths Prediction with Machine Learning

# %% [markdown]
# #### Let's import required libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### And load the dataset

# %%
data = pd.read_csv("Data/COVID19 data for overall INDIA.txt")
print(data.head())
# Out:
#               Date    Date_YMD  Daily Confirmed  Daily Deceased
# 0  30 January 2020  2020-01-30                1               0
# 1  31 January 2020  2020-01-31                0               0
# 2  1 February 2020  2020-02-01                0               0
# 3  2 February 2020  2020-02-02                1               0
# 4  3 February 2020  2020-02-03                1               0

# %% [markdown]
# #### Let's check if there are null values in the dataset

# %%
data.isnull().sum()
# Out:
# Date               0
# Date_YMD           0
# Daily Confirmed    0
# Daily Deceased     0
# dtype: int64

# %% [markdown]
# ##### As we can see, there no null values in the data. That's good.

# %% [markdown]
# #### Let's have a look at the daily confirmed cases of Covid.

# %%
import plotly.express as px

fig = px.bar(data, x='Date_YMD', y='Daily Confirmed')
fig.show()

# %% [markdown]
# #### In the above plot, we can see a high wave of Covid-19 cases between April 2021 and May 2021.
